# %% [markdown]
# Author: Pallavi Krishna
# PEP 8 Guidelines are some of the coding conventions used for Python.
# Although it is not necessary to follow it to use Python,
# it often helps in increasing the readability of code and
# hence durability, re-use, ease of maintenance etc
#
# In this program we will first identify the parts of the
# provided code that do not adhere to PEP 8, and then
# rework the same code to match PEP 8 guidelines
#
# Date: 16/01/2023

# %%
# Program To Make Simple Calculator
# This function adds 2numbers

def add( x, y ):    ''' There are additional unnecessary spaces in this line, def add_user_defined(x, y) is better
                        In addition add is a function that already exists in Python, and this program
                        will override the original add function. It is better to use a different name
                    '''
    return x + y    # extra spaces can be taken out here 
#This function subtracts  2numbers # a space can be added here before the #
def subtract(x, y):  ''' subtract is a function that already exists in Python, and this program
                        will override the original subtract function. It is better to use a different name.
                        subtract_user_defined(x, y) is better
                     '''
    return x - y    # extra spaces can be taken out here 
                    # Two blank lines can be removed here


       #This function multipliers 2numbers # It is better to allign to the other comments in the program
def multiply(x, y):   ''' multiply is a function that already exists in Python, and this program
                        will override the original multiply function. It is better to use a different name.
                        multiply_user_defined(x, y) is better
                      '''
   return x * y       # extra spaces can be taken out here + indentation to be rectified
                      # Additional blank line can be added here
##This function divides  2numbers #take away one # in the beginning and replace it with space
def divide(x, y):   ''' divide is a function that already exists in Python, and this program
                        will override the original divide function. It is better to use a different name.
                        divide_user_defined(x, y) is better
                      '''
   return x / y       # extra spaces can be taken out here + indentation to be rectified

print ( "Select operation.")   # Remove unnecessary spaces in this and the next 4 statements
print ( "1.Add")               # The correct way would be print("Select operation.") and similary for the rest
print ( "2.Subtract")
print ( "3.Multiply")
print ( "4.Divide")

while True:         # A comment can be added here as to what is being checked by the while loop
   
   choice = input  ("Enter choice(1/2/3/4): ")# Take input from the  user #this explains the obvious and is not needed
                                              # we don't need the spaces after input
   # Check if choice is 1 of the four options by completing the following code in the IDE of your choice or notebook
   if choice in ('1', '2', '3', '4'):
      Num1   = float(input("Enter first number: ")) # separate the numeric from alphanumeric with an underscore - num_1
      Num2   = float(input("Enter second number: ")) # separate the numeric from alphanumeric with an underscore

       if CHOICE == '1':    # CHOICE and choice are different in python, so this should be choice and not CHOICE
           print(Num1, "+", Num2, "=", add( Num1, Num2 )) #there is no need of spaces in the add function - use add(Num1, Num2)

       elif CHOICE == '2':  # CHOICE and choice are different in python, so this should be choice and not CHOICE
           print (Num1, "-", Num2, "=", subtract( Num1, Num2 )) # there is no need of spaces in the subtract function 
                                                                # - use subtract(Num1, Num2)

       elif CHOICE == '3':  #CHOICE and choice are different in python, so this should be choice and not CHOICE
           print (Num1, "*", Num2, "=", multiply( Num1, Num2 )) # there is no need of spaces in the multiply function 
                                                                # - use multiply(Num1, Num2)

       elif CHOICE == '4':  #CHOICE and choice are different in python, so this should be choice and not CHOICE
           print (Num1, "/", Num2, "=", divide( Num1, Num2 ))   # there is no need of spaces in the divide function 
                                                                # - use divide(Num1, Num2)
       break  #=     
   else: # Wrong indentation

       Print( "Invalid Input" )# this prints the invalid input.... # the comment is explanatory and not needed
                                                                   # Print is incorrect, should be print("Invalid Input")
# Out:
#   Input In [6]
#     return x + y    # extra spaces can be taken out here
#     ^
# IndentationError: unexpected indent

# %%
# Program To Make Simple Calculator after PEP 8 changes

# This function adds 2numbers
def add_user_defined(x, y):    
    return x+y    

# This function subtracts 2numbers
def subtract_user_defined(x, y):  
    return x-y    

# This function multiplies 2numbers 
def multiply_user_defined(x, y):   
    return x*y      

# This function divides 2numbers 
def divide_user_defined(x, y):   
   return x/y    

print("Select operation.")
print("1.Add")
print("2.Subtract")
print("3.Multiply")
print("4.Divide")

# While the user enters a valid selection, perform the code inside
while True:            
   choice = input("Enter choice(1/2/3/4): ")
    
   # Check if choice is 1 of the four options 
   if choice in ('1', '2', '3', '4'):
      num_1   = float(input("Enter first number: ")) 
      num_2   = float(input("Enter second number: ")) 

      if choice == '1':    
          print(num_1, "+",num_2, "=", add_user_defined(num_1, num_2)) 
      elif choice == '2':  
          print (num_1, "-",num_2, "=", subtract_user_defined( num_1,num_2 )) 
      elif choice == '3':  
          print (num_1, "*",num_2, "=", multiply_user_defined( num_1,num_2 )) 
      elif choice == '4':  
          print (num_1, "/",num_2, "=", divide_user_defined( num_1,num_2 ))  
      break;
else:
    print( "Invalid Input" )
# Out:
# Select operation.
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# Enter choice(1/2/3/4): 1
# Enter first number: 2
# Enter second number: 3
# 2.0 + 3.0 = 5.0
